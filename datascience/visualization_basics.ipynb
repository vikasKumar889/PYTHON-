# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.array([0,3,4,5,6,2,10,15,20])
_ =plt.plot(data)

# %%
data = np.array([0,5,10,15,20,15,10,5,10,5,10])
_ =plt.plot(data)

# %%
data = np.array([0,5,10,15,20,15,10,5,10,5,10])
plt.plot(data)
plt.savefig('demo1.png')

# %%
x = np.array([12,45,67,89,34])
y = np.array([45,67,89,12,34])
_ = plt.plot(x,y,'o--') #o-- is a line with dots

# %%
# staircase
x = np.array([0,10,10,20,20,30,30,40,40])
y = np.array([0,0,10,10,20,20,30,30,40])
plt.text(2,6,'staircase',color='red',fontsize=20)
plt.plot(x,y,'r*:')
#_ = plt.plot(x,y,'o--')

# %%
plt.plot?
# Out:
# Signature: plt.plot(*args, scalex=True, scaley=True, data=None, **kwargs)
# Docstring:
# Plot y versus x as lines and/or markers.
#
# Call signatures::
#
#     plot([x], y, [fmt], *, data=None, **kwargs)
#     plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
# The coordinates of the points or line nodes are given by *x*, *y*.
#
# The optional parameter *fmt* is a convenient way for defining basic
# formatting like color, marker and linestyle. It's a shortcut string
# notation described in the *Notes* section below.
#
# >>> plot(x, y)        # plot x and y using default line style and color
# >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
# >>> plot(y)           # plot y using x as index array 0..N-1
# >>> plot(y, 'r+')     # ditto, but with red plusses
#
# You can use `.Line2D` properties as keyword arguments for more
# control on the appearance. Line properties and *fmt* can be mixed.
# The following two calls yield identical results:
#
# ...

# %%
x = np.arange(-10,10,0.1)
print(x.shape)
# Out:
# (200,)

# %%
x2 = x ** 2 # square of x

# %%
plt.plot(x,x2)

# %%
x3 = x ** 3

# %%
plt.figure(figsize=(15,7)) # create a fig with a size of 15*7
plt.plot(x, label='original',linestyle='--')
plt.plot(x2, label='squared',linestyle=':')
plt.plot(x3,label='cubed')
plt.legend()
plt.xlabel('Data points')
plt.ylabel('Values of x')
plt.title('The visualization of X and its square and cube')# add a title to the fig
plt.show() #show the fig

# %%
cities = ['lucknow','delhi','mumbai','pune','bangalore']
rainfall = [39,20,63,45,78]

# %%
plt.plot(cities,rainfall,'o--')

# %%
plt.bar(cities,rainfall)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(cities,rainfall)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=(10,7))
plt.bar(cities,rainfall, color='red',edgecolor='black',hatch='//', width = .7)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(facecolor='white')
plt.pie(rainfall, labels=cities, autopct='%1.1f%%',radius=2)
plt.show()

# %%
plt.figure(facecolor='white')
wedges = [0,.3,0,0,0]
plt.pie(rainfall, labels=cities, autopct='%1.1f%%',radius=2,explode=wedges)
plt.show()

# %%
prices = [213,34,46,78,45,67,5,78,34,56,23]
qty = [12,45,56,89,34,23,12,45,23,56,78]
len(prices) == len(qty)
# Out:
# True

# %%
plt.scatter(prices,qty)

# %%
plt.scatter(prices,qty,color='green',marker='s',s=100*3,alpha=.5)
plt.scatter(prices,q)

# %%
x = np.random.randint(1,10,500)

# %%
plt.hist(x, bins=10,color='green',range=(0,10),align='left')
plt.hist(y, bins=10,color='blue',range=(1,10),align='left',alpha=0.5)
_=plt.xticks(np.arange(0,11,1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\91969\Documents\python\datascience\visualization_basics.ipynb Cell 22' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/91969/Documents/python/datascience/visualization_basics.ipynb#ch0000021?line=0'>1</a> plt.hist(x, bins=10,color='green',range=(0,10),align='left')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/91969/Documents/python/datascience/visualization_basics.ipynb#ch0000021?line=1'>2</a> plt.hist(y, bins=10,color='blue',range=(1,10),align='left',alpha=0.5)
#       <a href='vscode-notebook-cell:/c%3A/Users/91969/Documents/python/datascience/visualization_basics.ipynb#ch0000021?line=2'>3</a> _=plt.xticks(np.arange(0,11,1))
#
# NameError: name 'y' is not defined
